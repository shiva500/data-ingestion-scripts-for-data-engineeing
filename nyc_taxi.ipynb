# %%
import pandas as pd

# %%
df = pd.read_parquet('yellow_tripdata_2024-01.parquet')

# Display the first few rows
df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2024-01-01 00:57:55   2024-01-01 01:17:43              1.0
# 1         1  2024-01-01 00:03:00   2024-01-01 00:09:36              1.0
# 2         1  2024-01-01 00:17:06   2024-01-01 00:35:01              1.0
# 3         1  2024-01-01 00:36:38   2024-01-01 00:44:56              1.0
# 4         1  2024-01-01 00:46:51   2024-01-01 00:52:57              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           1.72         1.0                  N           186            79
# 1           1.80         1.0                  N           140           236
# 2           4.70         1.0                  N           236            79
# 3           1.40         1.0                  N            79           211
# 4           0.80         1.0                  N           211           148
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
df.columns
# Out:
# Index(['VendorID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime',
#        'passenger_count', 'trip_distance', 'RatecodeID', 'store_and_fwd_flag',
#        'PULocationID', 'DOLocationID', 'payment_type', 'fare_amount', 'extra',
#        'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge',
#        'total_amount', 'congestion_surcharge', 'Airport_fee'],
#       dtype='object')

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
print(pd.io.sql.get_schema(df, name='yellow_taxi_data'))
# Out:
# CREATE TABLE "yellow_taxi_data" (
# "VendorID" INTEGER,
#   "tpep_pickup_datetime" TIMESTAMP,
#   "tpep_dropoff_datetime" TIMESTAMP,
#   "passenger_count" REAL,
#   "trip_distance" REAL,
#   "RatecodeID" REAL,
#   "store_and_fwd_flag" TEXT,
#   "PULocationID" INTEGER,
#   "DOLocationID" INTEGER,
#   "payment_type" INTEGER,
#   "fare_amount" REAL,
#   "extra" REAL,
#   "mta_tax" REAL,
#   "tip_amount" REAL,
#   "tolls_amount" REAL,
#   "improvement_surcharge" REAL,
#   "total_amount" REAL,
#   "congestion_surcharge" REAL,
#   "Airport_fee" REAL
# )

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql://root:root@localhost:5432/ny_taxi')

# %%
print(pd.io.sql.get_schema(df, name='yellow_taxi_data', con=engine))
# Out:
# CREATE TABLE yellow_taxi_data (
# 	"VendorID" INTEGER,
# 	tpep_pickup_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	tpep_dropoff_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	passenger_count FLOAT(53),
# 	trip_distance FLOAT(53),
# 	"RatecodeID" FLOAT(53),
# 	store_and_fwd_flag TEXT,
# 	"PULocationID" INTEGER,
# 	"DOLocationID" INTEGER,
# 	payment_type BIGINT,
# 	fare_amount FLOAT(53),
# 	extra FLOAT(53),
# 	mta_tax FLOAT(53),
# 	tip_amount FLOAT(53),
# 	tolls_amount FLOAT(53),
# 	improvement_surcharge FLOAT(53),
# 	total_amount FLOAT(53),
# 	congestion_surcharge FLOAT(53),
# 	"Airport_fee" FLOAT(53)
# )

# %%
import pyarrow.parquet as pq

# Open the Parquet file
df_itr = pq.ParquetFile('yellow_tripdata_2024-01.parquet')

# Check the number of row groups
print(f"Number of row groups: {df_itr.num_row_groups}")

# Get metadata for each row group
for i in range(df_itr.num_row_groups):
    row_group = df_itr.metadata.row_group(i)
    print(f"Row Group {i}: {row_group.num_rows} rows, {row_group.total_byte_size / (1024 * 1024):.2f} MB")
# Out:
# Number of row groups: 3
# Row Group 0: 1048576 rows, 26.93 MB
# Row Group 1: 1048576 rows, 26.66 MB
# Row Group 2: 867472 rows, 21.60 MB

# %%
# # Define chunk size
# chunk_size = 100000

# # Read and insert data in chunks
# for chunk in pd.read_parquet("yellow_tripdata_2024-01.parquet", engine="pyarrow", iterator=True):
#     chunk.to_sql(TABLE_NAME, engine, if_exists="append", index=False)
#     print(f"Inserted {len(chunk)} rows into {TABLE_NAME}")

# %%
# %time df.to_sql(name="yellow_taxi_data", con=engine, if_exists = 'append')
# Out:
# CPU times: user 2min 34s, sys: 12.7 s, total: 2min 47s
# Wall time: 4min 31s
# 624

# %%
#alternative using sqlalchemy
from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql://root:root@localhost:5432/ny_taxi')

# %%
#test connection
engine.connect()

# %%
query = """
SELECT 1 as number;
"""

pd.read_sql(query, con=engine)
# Out:
#    number
# 0       1

# %%
query = """
SELECT *
FROM pg_catalog.pg_tables
WHERE schemaname != 'pg_catalog' AND
      schemaname != 'information_schema';
"""

pd.read_sql(query, con=engine)
# Out:
# Empty DataFrame
# Columns: [schemaname, tablename, tableowner, tablespace, hasindexes, hasrules, hastriggers, rowsecurity]
# Index: []

# %%
df.to_sql(name='yellow_tripdata_trip', con= engine, index=False)
# Out:
# 624

# %%
query = """
SELECT *
FROM yellow_tripdata_trip LIMIT 10;
"""

pd.read_sql(query, con=engine)
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2024-01-01 00:57:55   2024-01-01 01:17:43              1.0
# 1         1  2024-01-01 00:03:00   2024-01-01 00:09:36              1.0
# 2         1  2024-01-01 00:17:06   2024-01-01 00:35:01              1.0
# 3         1  2024-01-01 00:36:38   2024-01-01 00:44:56              1.0
# 4         1  2024-01-01 00:46:51   2024-01-01 00:52:57              1.0
# 5         1  2024-01-01 00:54:08   2024-01-01 01:26:31              1.0
# 6         2  2024-01-01 00:49:44   2024-01-01 01:15:47              2.0
# 7         1  2024-01-01 00:30:40   2024-01-01 00:58:40              0.0
# 8         2  2024-01-01 00:26:01   2024-01-01 00:54:12              1.0
# 9         2  2024-01-01 00:28:08   2024-01-01 00:29:16              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           1.72         1.0                  N           186            79
# ...
